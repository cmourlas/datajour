# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests, datetime

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
import requests

url = "https://api.darksky.net/forecast/51a8966601d916d5638a8ae554b95618/37.9833333,23.7333333?units=si"

response = requests.get(url)
print(response)

data = response.json()
# Out:
# <Response [200]>

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'offset', 'currently', 'hourly', 'daily', 'flags'])

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
data['currently']

forecast_currently = data['currently']
print(forecast_currently)
# Out:
# {'time': 1496586109, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0.0254, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 26.28, 'apparentTemperature': 26.28, 'dewPoint': 16.07, 'humidity': 0.53, 'windSpeed': 0.85, 'windBearing': 35, 'cloudCover': 0.2, 'pressure': 1012.29, 'ozone': 349.11}

# %%
print(data['currently']['windSpeed'], "is the current wind speed.")
# Out:
# 0.85 is the current wind speed.

# %%
apparent = forecast_currently['apparentTemperature']
actual = forecast_currently['temperature']

difference = apparent - actual

# e.g difference = 5

if (difference > 0):
  print(" It feels  ", difference, " degrees warmer than it actually is!")
elif (difference < 0):
  print(" It feels ", abs(difference), " degrees colder than it actually is!")
else:
  print("The difference is zero, so it does not feel warmer than it actually is, because the temperatures are the same!")
# Out:
# The difference is zero, so it does not feel warmer than it actually is, because the temperatures are the same!

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
#data['daily']

forecast_daily = data['daily']
# data_daily
#type(data_daily)

# print(forecast_daily.keys())
# forecast_daily

daily_data = forecast_daily['data']


first_daily_data = daily_data[0]

print(first_daily_data.keys())
# Out:
# dict_keys(['time', 'summary', 'icon', 'sunriseTime', 'sunsetTime', 'moonPhase', 'precipIntensity', 'precipIntensityMax', 'precipIntensityMaxTime', 'precipProbability', 'precipType', 'temperatureMin', 'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin', 'apparentTemperatureMinTime', 'apparentTemperatureMax', 'apparentTemperatureMaxTime', 'dewPoint', 'humidity', 'windSpeed', 'windBearing', 'cloudCover', 'pressure', 'ozone'])

# %% [markdown]
# type(daily_data)

# %%
print(int(100* first_daily_data['moonPhase']), "% of the moon is currently visible.")
# Out:
# 34 % of the moon is currently visible.

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
print((daily_data[0]['temperatureMax']) - (daily_data[0]['temperatureMin']), "°C is the difference between the high and low temperatures for today.")
# Out:
# 8.34 °C is the difference between the high and low temperatures for today.

# %%
daily_data
# Out:
# [{'apparentTemperatureMax': 26.54,
#   'apparentTemperatureMaxTime': 1496232000,
#   'apparentTemperatureMin': 7.53,
#   'apparentTemperatureMinTime': 1496196000,
#   'cloudCover': 0.01,
#   'dewPoint': 9.57,
#   'humidity': 0.63,
#   'icon': 'clear-day',
#   'moonPhase': 0.21,
#   'ozone': 347.47,
#   'precipIntensity': 0.0178,
#   'precipIntensityMax': 0.066,
#   'precipIntensityMaxTime': 1496246400,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'pressure': 1019,
#   'summary': 'Clear throughout the day.',
#   'sunriseTime': 1496200237,
#   'sunsetTime': 1496253186,
#   'temperatureMax': 26.54,
#   'temperatureMaxTime': 1496232000,
#   'temperatureMin': 8.39,
#   'temperatureMinTime': 1496196000,
#   'time': 1496178000,
#   'windBearing': 250,
#   'windSpeed': 1.63},
#  {'apparentTemperatureMax': 28.96,
#   'apparentTemperatureMaxTime': 1496318400,
#   'apparentTemperatureMin': 11.09,
#   'apparentTemperatureMinTime': 1496282400,
#   'cloudCover': 0.07,
# ...

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
for day in daily_data:
    timestamp = datetime.datetime.fromtimestamp(day['time']).strftime('%m.%d.%Y')
    if day['temperatureMax'] <+ 10:
        print(timestamp, "it will be cold. Take a jacket with you!")
    elif day['temperatureMax'] < 20:
        print(timestamp, "it will be warm. Nice day for a walk!")
    elif day['temperatureMax'] >=20:
        print(timestamp, "it will be hot!Don't forget you are in Greece!")
# Out:
# 06.04.2017 it will be hot!Don't forget you are in Greece!
# 06.05.2017 it will be hot!Don't forget you are in Greece!
# 06.06.2017 it will be hot!Don't forget you are in Greece!
# 06.07.2017 it will be hot!Don't forget you are in Greece!
# 06.08.2017 it will be hot!Don't forget you are in Greece!
# 06.09.2017 it will be hot!Don't forget you are in Greece!
# 06.10.2017 it will be hot!Don't forget you are in Greece!
# 06.11.2017 it will be hot!Don't forget you are in Greece!

# %%
type(daily_data)
# Out:
# list

# %%
# 6) What will be the hottest day in the next week? What is the high temperature on that day?

It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.

- *Tip: It's okay to skip this if it seems too difficult!*

# %%
hottest_temperature = (daily_data[0]['temperatureMax'])
for hot_day in daily_data:
    #print("Hello")
    #print(type(hot_day['temperatureMax']), type(hottest_temperature))
    timestamp = datetime.datetime.fromtimestamp(int(hot_day['time'])).strftime('%m.%d.%Y')
    if hot_day['temperatureMax'] > hottest_temperature:
        hottest_temperature = hot_day['temperatureMax']
print("The hottest will be at", timestamp, "the temperature will be", hottest_temperature, "°C.")
# Out:
# The hottest will be at 06.07.2017 the temperature will be 30.41 °C.

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
import requests
url = "https://api.darksky.net/forecast/63cf8148de6fe49d0aa7d305bf81bc6b/25.761680,-80.191790"

response = requests.get(url)
print(response)

data_Maimi = response.json()
# Out:
# <Response [200]>

# %%
#type(data_Maimi)
data_Maimi.keys()
Maimi_hourly = data_Maimi['hourly']
type(Maimi_hourly)
hourly = Maimi_hourly['data']
hourly
# Out:
# [{'apparentTemperature': 85.2,
#   'cloudCover': 1,
#   'dewPoint': 73.64,
#   'humidity': 0.8,
#   'icon': 'rain',
#   'ozone': 283.78,
#   'precipIntensity': 0.1143,
#   'precipProbability': 0.81,
#   'precipType': 'rain',
#   'pressure': 1015.98,
#   'summary': 'Rain',
#   'temperature': 80.46,
#   'time': 1496584800,
#   'visibility': 8.23,
#   'windBearing': 90,
#   'windSpeed': 11.66},
#  {'apparentTemperature': 88.29,
#   'cloudCover': 1,
#   'dewPoint': 74.73,
#   'humidity': 0.79,
#   'icon': 'rain',
#   'ozone': 284.07,
#   'precipIntensity': 0.0177,
#   'precipProbability': 0.75,
#   'precipType': 'rain',
#   'pressure': 1015.97,
#   'summary': 'Light Rain',
#   'temperature': 81.89,
#   'time': 1496588400,
#   'visibility': 8.49,
#   'windBearing': 90,
#   'windSpeed': 11.64},
#  {'apparentTemperature': 88.64,
#   'cloudCover': 1,
#   'dewPoint': 74.56,
#   'humidity': 0.78,
#   'icon': 'rain',
#   'ozone': 284.71,
#   'precipIntensity': 0.0354,
# ...

# %%
for hour in hourly:
    timestamp1 = datetime.datetime.utcfromtimestamp(hour['time']).strftime('%m.%d.%Y.%H.%M')
    if hour['cloudCover']< float(0.50):
        print("At",timestamp1, "will not be cloudy!")
    elif hour['cloudCover']> float(0.50):
        print("At",timestamp1, "it will be cloudy!")
# Out:
# At 06.04.2017.14.00 it will be cloudy!
# At 06.04.2017.15.00 it will be cloudy!
# At 06.04.2017.16.00 it will be cloudy!
# At 06.04.2017.17.00 it will be cloudy!
# At 06.04.2017.18.00 it will be cloudy!
# At 06.04.2017.19.00 it will be cloudy!
# At 06.04.2017.20.00 it will be cloudy!
# At 06.04.2017.21.00 it will be cloudy!
# At 06.04.2017.22.00 it will be cloudy!
# At 06.04.2017.23.00 it will be cloudy!
# At 06.05.2017.00.00 it will be cloudy!
# At 06.05.2017.01.00 it will be cloudy!
# At 06.05.2017.02.00 it will be cloudy!
# At 06.05.2017.03.00 it will be cloudy!
# At 06.05.2017.04.00 it will be cloudy!
# At 06.05.2017.05.00 it will be cloudy!
# At 06.05.2017.06.00 it will be cloudy!
# At 06.05.2017.07.00 it will be cloudy!
# At 06.05.2017.08.00 it will be cloudy!
# At 06.05.2017.09.00 it will be cloudy!
# At 06.05.2017.10.00 it will be cloudy!
# At 06.05.2017.11.00 it will be cloudy!
# At 06.05.2017.12.00 it will be cloudy!
# At 06.05.2017.13.00 it will be cloudy!
# ...

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
value = 0
value1 = 0
for i in hourly[0:24]:
    if i['temperature'] > 85:
        value += 1
    if i['temperature'] < 85:
        value1 += 1
        
print(round(value * 100/ 24), "% of the time is the temperature above 85 degrees.")
# Out:
# 54 % of the time is the temperature above 85 degrees.

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
import requests
url = "https://api.darksky.net/forecast/63cf8148de6fe49d0aa7d305bf81bc6b/40.785091,-73.968285,1356443188?exclude=currently,flags"

response = requests.get(url)
print(response)

data_Central= response.json()
# Out:
# <Response [200]>

# %%
#The time is 15:45 pm from https://www.epochconverter.com/  and the average temperature is the mean of temperatureMax and tMin.
data_Central.keys()
Central_daily = data_Central['daily']
#type(Central_daily)
daily = Central_daily['data']
print(len([daily[0]['temperatureMin'], daily[0]['temperatureMax']]))
# Out:
# 2

# %%
import statistics as s

mean_temp_2012 = s.mean([daily[0]['temperatureMin'], daily[0]['temperatureMax']])

print(mean_temp_2012, "F was the temperature in Central Park on Christmas Day, 2012")
# Out:
# 37.1 F was the temperature in Central Park on Christmas Day, 2012

# %%
import requests
url = "https://api.darksky.net/forecast/63cf8148de6fe49d0aa7d305bf81bc6b/40.785091,-73.968285,1198590388?exclude=currently,flags"

response = requests.get(url)
print(response)

data_Central_2007= response.json() 

#The time is 15:45 pm from https://www.epochconverter.com/
data_Central_2007.keys()
Central_daily_2007 = data_Central_2007['daily']
type(Central_daily_2007)
daily_2007 = Central_daily_2007['data']

mean_temp_2007 = s.mean([daily_2007[0]['temperatureMin'], daily_2007[0]['temperatureMax']])

print("%.2f" % mean_temp_2007, "F was the temperature in Central Park on Christmas Day, 2007")
# Out:
# <Response [200]>
# 39.46 F was the temperature in Central Park on Christmas Day, 2007

# %%
import requests
url = "https://api.darksky.net/forecast/63cf8148de6fe49d0aa7d305bf81bc6b/40.785091,-73.968285,1135518388?exclude=currently,flags"

response = requests.get(url)
print(response)

data_Central_2005= response.json() 

#The time is 15:45 pm from https://www.epochconverter.com/
data_Central_2005.keys()
Central_daily_2005 = data_Central_2005['daily']
type(Central_daily_2005)
daily_2005 = Central_daily_2005['data']
daily_2005
# Out:
# <Response [200]>
# [{'apparentTemperatureMax': 51.92,
#   'apparentTemperatureMaxTime': 1135562400,
#   'apparentTemperatureMin': 32.87,
#   'apparentTemperatureMinTime': 1135497600,
#   'cloudCover': 0.82,
#   'dewPoint': 39.16,
#   'humidity': 0.88,
#   'icon': 'rain',
#   'moonPhase': 0.81,
#   'precipIntensity': 0.0193,
#   'precipIntensityMax': 0.1387,
#   'precipIntensityMaxTime': 1135562400,
#   'precipProbability': 0.83,
#   'precipType': 'rain',
#   'pressure': 1007.86,
#   'summary': 'Rain starting in the afternoon.',
#   'sunriseTime': 1135513189,
#   'sunsetTime': 1135546494,
#   'temperatureMax': 51.92,
#   'temperatureMaxTime': 1135562400,
#   'temperatureMin': 36.16,
#   'temperatureMinTime': 1135497600,
#   'time': 1135486800,
#   'visibility': 3.86,
#   'windBearing': 77,
#   'windSpeed': 3.52}]

# %%
mean_temp_2005 = s.mean([daily_2005[0]['temperatureMin'], daily_2005[0]['temperatureMax']])

print("%.2f" % mean_temp_2005, "F was the temperature in Central Park on Christmas Day, 2005")
# Out:
# 44.04 F was the temperature in Central Park on Christmas Day, 2005

# %%
import requests
url = "https://api.darksky.net/forecast/63cf8148de6fe49d0aa7d305bf81bc6b/40.785091,-73.968285,-2145878012?exclude=currently,flags"

response = requests.get(url)
print(response)

data_Central_test= response.json() 

#-2145878012 is 1 January 1902 10:46:28 AM
# Out:
# <Response [400]>

# %%
data_Central_test['daily']
# Out:
# {'data': [{'apparentTemperatureMax': 47.64,
#    'apparentTemperatureMaxTime': -34840800,
#    'apparentTemperatureMin': 31.66,
#    'apparentTemperatureMinTime': -34866000,
#    'cloudCover': 0.43,
#    'dewPoint': 27.72,
#    'humidity': 0.57,
#    'icon': 'partly-cloudy-night',
#    'moonPhase': 0.13,
#    'precipIntensity': 0,
#    'precipProbability': 0,
#    'pressure': 1022.59,
#    'summary': 'Mostly cloudy throughout the day.',
#    'sunriseTime': -34862720,
#    'sunsetTime': -34827992,
#    'temperatureMax': 49.96,
#    'temperatureMaxTime': -34840800,
#    'temperatureMin': 36.29,
#    'temperatureMinTime': -34815600,
#    'time': -34887600,
#    'visibility': 9.56,
#    'windBearing': 250,
#    'windSpeed': 5.31}]}

# %%
print(response, "It allows me to take data since 1902.")
# Out:
# <Response [200]> It allows me to take data since 1902.
